# %%
import numpy as np
import pandas as pd

import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 6

# %%
dataset = pd.read_csv("sales+monthly.csv")
# Parse string to datetime type
dataset['datum'] = pd.to_datetime(dataset['datum'], infer_datetime_format=True)
indexedDataset = dataset.set_index(['datum'])

# %%
from datetime import datetime
indexedDataset.head(5)
# Out:
#               sales
# datum
# 2014-01-31  152.100
# 2014-02-28  177.000
# 2014-03-31  147.655
# 2014-04-30  130.900
# 2014-05-31  132.100

# %%
plt.xlabel("Date")
plt.ylabel("sales")
indexedDataset = indexedDataset.drop(indexedDataset.index[-1])
plt.plot(indexedDataset)

# %%
#Determing rolling statistics
rolmean = indexedDataset.rolling(window=12).mean()

rolstd = indexedDataset.rolling(window=12).std()

print(rolmean,rolstd)
# Out:
#                 sales
# datum
# 2014-01-31        NaN
# 2014-02-28        NaN
# 2014-03-31        NaN
# 2014-04-30        NaN
# 2014-05-31        NaN
# ...               ...
# 2019-05-31  91.429167
# 2019-06-30  92.795833
# 2019-07-31  93.262500
# 2019-08-31  92.925000
# 2019-09-30  93.508333
#
# [69 rows x 1 columns]                 sales
# datum
# 2014-01-31        NaN
# 2014-02-28        NaN
# 2014-03-31        NaN
# 2014-04-30        NaN
# 2014-05-31        NaN
# ...               ...
# 2019-05-31  10.123969
# 2019-06-30  10.540624
# 2019-07-31  10.393292
# 2019-08-31  10.633833
# 2019-09-30  10.439563
#
# [69 rows x 1 columns]

# %%
#rolling mean method for determine stationarity

orig = plt.plot(indexedDataset, color='blue', label='Original')
mean = plt.plot(rolmean, color='red', label="Rolling Mean")
std = plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean and Standard Deviation')
plt.show(block=False)

# %%
#Dickey-fuller test
from statsmodels.tsa.stattools import adfuller

print ('Results of Dickey-Fuller Test: ')
dftest = adfuller(indexedDataset['sales'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistics','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    

print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistics                -1.960302
# p-value                         0.304246
# #Lags Used                      2.000000
# Number of Observations Used    66.000000
# Critical Value (1%)            -3.533560
# Critical Value (5%)            -2.906444
# Critical Value (10%)           -2.590724
# dtype: float64

# %%
indexedDataset_logScale = np.log(indexedDataset)
plt.plot(indexedDataset_logScale)

# %%
movingAverage = indexedDataset_logScale.rolling(window=12).mean()
movingSTD = indexedDataset_logScale.rolling(window=12).std()
plt.plot(indexedDataset_logScale)
plt.plot(movingAverage, color='red')

# %%
datasetLogScaleMinusMovingAverage = indexedDataset_logScale - movingAverage
datasetLogScaleMinusMovingAverage.head(12)

datasetLogScaleMinusMovingAverage.dropna(inplace=True)
datasetLogScaleMinusMovingAverage.head(10)
# Out:
#                sales
# datum
# 2014-12-31 -0.220801
# 2015-01-31  0.023627
# 2015-02-28 -0.019067
# 2015-03-31  0.003977
# 2015-04-30 -0.081729
# 2015-05-31  0.023930
# 2015-06-30  0.076838
# 2015-07-31 -0.068271
# 2015-08-31 -0.013449
# 2015-09-30 -0.194296

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    #Determing rolling statistics
    movingAverage = timeseries.rolling(window=12).mean()
    movingSTD = timeseries.rolling(window=12).std()
    
    #plot rolling statistics:
    orig = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
    std = plt.plot(movingSTD, color='black', label ='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling mean and standard deviation')
    plt.show(block=False)
    
    #perform dickey-fuller test:
    
    dftest = adfuller(timeseries['sales'], autolag='AIC')

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistics','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    

    print(dfoutput)

# %%
test_stationarity(datasetLogScaleMinusMovingAverage)
# Out:
# Test Statistics                -5.451869
# p-value                         0.000003
# #Lags Used                      0.000000
# Number of Observations Used    57.000000
# Critical Value (1%)            -3.550670
# Critical Value (5%)            -2.913766
# Critical Value (10%)           -2.594624
# dtype: float64

# %%
exponentialDecayWeightedAverage = indexedDataset_logScale.ewm(halflife=12, min_periods=0, adjust=True).mean()
plt.plot(indexedDataset_logScale)
plt.plot(exponentialDecayWeightedAverage, color='red')

# %%
datasetLogScaleMinusMovingExponenttialDecayAverage = indexedDataset_logScale - exponentialDecayWeightedAverage
test_stationarity(datasetLogScaleMinusMovingExponenttialDecayAverage)
# Out:
# Test Statistics                -2.924851
# p-value                         0.042534
# #Lags Used                      2.000000
# Number of Observations Used    66.000000
# Critical Value (1%)            -3.533560
# Critical Value (5%)            -2.906444
# Critical Value (10%)           -2.590724
# dtype: float64

# %%
datasetLogdiffshifting = indexedDataset_logScale - indexedDataset_logScale.shift()
plt.plot(datasetLogdiffshifting)

# %%
datasetLogdiffshifting.dropna(inplace=True)
test_stationarity(datasetLogdiffshifting)
# Out:
# Test Statistics               -9.656458e+00
# p-value                        1.389951e-16
# #Lags Used                     1.000000e+00
# Number of Observations Used    6.600000e+01
# Critical Value (1%)           -3.533560e+00
# Critical Value (5%)           -2.906444e+00
# Critical Value (10%)          -2.590724e+00
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(indexedDataset_logScale)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(indexedDataset_logScale, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()


decomposedLogData = residual
decomposedLogData.dropna(inplace=True)
df = decomposedLogData.to_frame()
df = df.rename(columns={'resid': 'sales'})
test_stationarity(df)
# Out:
# Test Statistics                -5.512625
# p-value                         0.000002
# #Lags Used                      3.000000
# Number of Observations Used    53.000000
# Critical Value (1%)            -3.560242
# Critical Value (5%)            -2.917850
# Critical Value (10%)           -2.596796
# dtype: float64

# %%
#ACF and PACF Plots
from statsmodels.tsa.stattools import acf, pacf

lag_acf = acf(indexedDataset_logScale, nlags=10)
lag_pacf = pacf(indexedDataset_logScale, nlags=10, method='ols')

#plot ACF
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(indexedDataset_logScale)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(indexedDataset_logScale)),linestyle='--',color='gray')
plt.title('Autocorrealation Function')

#plot PACF
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(indexedDataset_logScale)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(indexedDataset_logScale)),linestyle='--',color='gray')
plt.title('Partial Autocorrealation Function')
plt.tight_layout()

# %%
from statsmodels.tsa.arima.model import ARIMA

# Shift the index of datasetLogdiffshifting["sales"]
# indexedDataset_logScale_shifted = indexedDataset_logScale.shift()

# AR Model
model = ARIMA(indexedDataset_logScale, order=(1,1,4))
results_ARIMA = model.fit()
# predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
# predictions_ARIMA_diff
fitted_values = results_ARIMA.fittedvalues.values

# Remove first two values from fitted results
# fitted_values = fitted_values[2:]
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
predictions_ARIMA_diff = predictions_ARIMA_diff[1:]
predictions_ARIMA_diff
# Out:
# c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# datum
# 2014-02-28    5.024538
# 2014-03-31    5.114566
# 2014-04-30    5.041378
# 2014-05-31    5.002949
# 2014-06-30    4.931539
#                 ...
# 2019-05-31    4.517348
# 2019-06-30    4.540224
# 2019-07-31    4.582071
# 2019-08-31    4.574458
# 2019-09-30    4.514978
# Length: 68, dtype: float64

# %%
from statsmodels.tsa.arima.model import ARIMA

# Shift the index of datasetLogdiffshifting["sales"]
# indexedDataset_logScale_shifted = indexedDataset_logScale.shift()
indexedDataset_logScale = indexedDataset_logScale.drop(indexedDataset_logScale.index[-1])
# AR Model
model = ARIMA(indexedDataset_logScale, order=(0,1,6))
results_AR = model.fit()

# Get fitted values and calculate RSS
fitted_values = results_AR.fittedvalues.dropna()
results_AR.fittedvalues = results_AR.fittedvalues[1:]
diff = fitted_values - indexedDataset_logScale["sales"].loc[fitted_values.index]
RSS = (diff ** 2).sum()

# Plot the results
plt.plot(indexedDataset_logScale["sales"])
plt.plot(results_AR.fittedvalues, color='red')
# plt.title('RSS: %.4f' % RSS)
# print('Plotting AR model')
# Out:
# c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
predictions_ARIMA_diff = predictions_ARIMA_diff[2:]
print(predictions_ARIMA_diff)
# Out:
# datum
# 2014-03-31    5.114566
# 2014-04-30    5.041378
# 2014-05-31    5.002949
# 2014-06-30    4.931539
# 2014-07-31    4.890364
#                 ...
# 2019-05-31    4.517348
# 2019-06-30    4.540224
# 2019-07-31    4.582071
# 2019-08-31    4.574458
# 2019-09-30    4.514978
# Length: 67, dtype: float64

# %%
predictions_ARIMA = pd.Series(indexedDataset_logScale['sales'].iloc[0], index=indexedDataset_logScale.index)
predictions_ARIMA = predictions_ARIMA.add(predictions_ARIMA_diff,fill_value=0)
predictions_ARIMA
# Out:
# datum
# 2014-01-31     5.024538
# 2014-02-28     5.024538
# 2014-03-31    10.139104
# 2014-04-30    10.065917
# 2014-05-31    10.027487
#                 ...
# 2019-05-31     9.541886
# 2019-06-30     9.564763
# 2019-07-31     9.606609
# 2019-08-31     9.598996
# 2019-09-30     4.514978
# Length: 69, dtype: float64

# %%
predictions_ARIMA=np.exp(predictions_ARIMA_diff)
plt.plot(indexedDataset)
plt.plot(predictions_ARIMA)

# %%
print(results_ARIMA.forecast(steps=2))
# Out:
# 2019-10-31    4.520596
# 2019-11-30    4.507971
# Freq: M, Name: predicted_mean, dtype: float64

# %%
results = results_ARIMA.forecast(steps=2)
finalres = np.exp(results)
my_df = finalres.to_frame()
my_df
# Out:
#             predicted_mean
# 2019-10-31       91.890339
# 2019-11-30       90.737508

# %%
my_df_1 = predictions_ARIMA.to_frame(name='predicted_mean')
my_df_1
# Out:
#             predicted_mean
# datum
# 2014-03-31      166.428458
# 2014-04-30      154.683073
# 2014-05-31      148.851485
# 2014-06-30      138.592681
# 2014-07-31      133.002040
# ...                    ...
# 2019-05-31       91.592354
# 2019-06-30       93.711821
# 2019-07-31       97.716535
# 2019-08-31       96.975445
# 2019-09-30       91.375554
#
# [67 rows x 1 columns]

# %%
concatenated_df = pd.concat([my_df_1, my_df])
concatenated_df
# Out:
#             predicted_mean
# 2014-03-31      166.428458
# 2014-04-30      154.683073
# 2014-05-31      148.851485
# 2014-06-30      138.592681
# 2014-07-31      133.002040
# ...                    ...
# 2019-07-31       97.716535
# 2019-08-31       96.975445
# 2019-09-30       91.375554
# 2019-10-31       91.890339
# 2019-11-30       90.737508
#
# [69 rows x 1 columns]

# %%
concatenated_df.to_csv('predictions.csv', index=True)

# %%
df = pd.read_csv("predictions.csv")
lst = df.values.tolist()
pred = pd.DataFrame(lst)
pred.columns = ['Year','Sales']
pred
# Out:
#           Year       Sales
# 0   2014-03-31  166.428458
# 1   2014-04-30  154.683073
# 2   2014-05-31  148.851485
# 3   2014-06-30  138.592681
# 4   2014-07-31  133.002040
# ..         ...         ...
# 64  2019-07-31   97.716535
# 65  2019-08-31   96.975445
# 66  2019-09-30   91.375554
# 67  2019-10-31   91.890339
# 68  2019-11-30   90.737508
#
# [69 rows x 2 columns]

# %%
import altair as alt
import datapane as dp
from vega_datasets import data

fig = (
    alt.Chart(pred)
    .mark_point()
    .encode(x=alt.X("Year", scale=alt.Scale(zero=False)), 
            y=alt.X("Sales", scale=alt.Scale(zero=False)))
)

view = dp.Select(dp.Plot(fig, label="Plot"), dp.DataTable(pred, label="Data"))
view
# dp.save_report(view, "quickstart_report.html", open=True)
# dp.upload_report(view, name="My Report")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\blocks\base.py:78, in BaseBlock._ipython_display_(self)
#      75 from datapane.view import Blocks
#      77 if get_environment().support_rich_display:
# ---> 78     html_str = stringify_report(Blocks(self))
#      79     display(HTML(html_str))
#      80 else:
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\processors\api.py:130, in stringify_report(blocks, name, formatting)
#     118 """Stringify the app document to a HTML string
#     119
#     120 Args:
#    (...)
#     123     formatting: Sets the basic app styling
#     124 """
#     126 s = ViewState(blocks=Blocks.wrap_blocks(blocks), file_entry_klass=B64FileEntry)
#     127 report_html: str = (
#     128     Pipeline(s)
#     129     .pipe(PreProcessView(is_finalised=False))
# --> 130     .pipe(ConvertXML())
#     131     .pipe(ExportHTMLStringInlineAssets(name=name, formatting=formatting))
#     132     .result
#     133 )
#     135 return report_html
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\processors\types.py:60, in Pipeline.pipe(self, p)
#      58 def pipe(self, p: BaseProcessor[P_IN, P_OUT]) -> Pipeline[P_OUT]:
#      59     p.s = self._state
# ---> 60     y = p.__call__(self._x)  # need to call as positional args
#      61     self._state = p.s
#      62     return Pipeline(self._state, y)
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\processors\processors.py:93, in ConvertXML.__call__(self, _)
#      92 def __call__(self, _: t.Any) -> ElementT:
# ---> 93     initial_doc = self.convert_xml()
#      94     transformed_doc = self.post_transforms(initial_doc)
#      96     # convert to string
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\processors\processors.py:110, in ConvertXML.convert_xml(self)
#     107 def convert_xml(self) -> ElementT:
#     108     # create initial state
#     109     builder_state = XMLBuilder(store=self.s.store)
# --> 110     self.s.blocks.accept(builder_state)
#     111     return builder_state.get_root(self.fragment)
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\blocks\base.py:84, in BaseBlock.accept(self, visitor)
#      83 def accept(self, visitor: VV) -> VV:
# ---> 84     visitor.visit(self)
#      85     return visitor
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\multimethod\__init__.py:315, in multimethod.__call__(self, *args, **kwargs)
#     313 func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except TypeError as ex:
#     317     raise DispatchError(f"Function {func.__code__}") from ex
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\view\xml_visitor.py:89, in XMLBuilder.visit(self, b)
#      87 @multimethod
#      88 def visit(self, b: Blocks) -> XMLBuilder:
# ---> 89     sub_elements = self._visit_subnodes(b)
#      91     # Blocks are converted to Group internally
#      92     if label := b._attributes.get("label"):
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\view\xml_visitor.py:74, in XMLBuilder._visit_subnodes(self, b)
#      72 cur_elements = self.elements
#      73 self.elements = []
# ---> 74 b.traverse(self)  # visit subnodes
#      75 res = self.elements
#      76 self.elements = cur_elements
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\blocks\layout.py:70, in ContainerBlock.traverse(self, visitor)
#      68 def traverse(self, visitor: VV) -> VV:
#      69     # perform a depth-first traversal of the contained blocks
# ---> 70     return reduce(lambda _visitor, block: block.accept(_visitor), self.blocks, visitor)
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\blocks\layout.py:70, in ContainerBlock.traverse.<locals>.<lambda>(_visitor, block)
#      68 def traverse(self, visitor: VV) -> VV:
#      69     # perform a depth-first traversal of the contained blocks
# ---> 70     return reduce(lambda _visitor, block: block.accept(_visitor), self.blocks, visitor)
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\blocks\base.py:84, in BaseBlock.accept(self, visitor)
#      83 def accept(self, visitor: VV) -> VV:
# ---> 84     visitor.visit(self)
#      85     return visitor
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\multimethod\__init__.py:315, in multimethod.__call__(self, *args, **kwargs)
#     313 func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except TypeError as ex:
#     317     raise DispatchError(f"Function {func.__code__}") from ex
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\view\xml_visitor.py:81, in XMLBuilder.visit(self, b)
#      79 @multimethod
#      80 def visit(self, b: ContainerBlock) -> XMLBuilder:
# ---> 81     sub_elements = self._visit_subnodes(b)
#      82     # build the element
#      83     _E = getattr(E, b._tag)
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\view\xml_visitor.py:74, in XMLBuilder._visit_subnodes(self, b)
#      72 cur_elements = self.elements
#      73 self.elements = []
# ---> 74 b.traverse(self)  # visit subnodes
#      75 res = self.elements
#      76 self.elements = cur_elements
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\blocks\layout.py:70, in ContainerBlock.traverse(self, visitor)
#      68 def traverse(self, visitor: VV) -> VV:
#      69     # perform a depth-first traversal of the contained blocks
# ---> 70     return reduce(lambda _visitor, block: block.accept(_visitor), self.blocks, visitor)
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\blocks\layout.py:70, in ContainerBlock.traverse.<locals>.<lambda>(_visitor, block)
#      68 def traverse(self, visitor: VV) -> VV:
#      69     # perform a depth-first traversal of the contained blocks
# ---> 70     return reduce(lambda _visitor, block: block.accept(_visitor), self.blocks, visitor)
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\blocks\base.py:84, in BaseBlock.accept(self, visitor)
#      83 def accept(self, visitor: VV) -> VV:
# ---> 84     visitor.visit(self)
#      85     return visitor
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\multimethod\__init__.py:315, in multimethod.__call__(self, *args, **kwargs)
#     313 func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except TypeError as ex:
#     317     raise DispatchError(f"Function {func.__code__}") from ex
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\view\xml_visitor.py:130, in XMLBuilder.visit(self, b)
#     127 @multimethod
#     128 def visit(self, b: AssetBlock):
#     129     """Main XMl creation method - visitor method"""
# --> 130     fe = self._add_asset_to_store(b)
#     132     _E = getattr(E, b._tag)
#     134     e: etree._Element = _E(
#     135         type=fe.mime,
#     136         # size=conv_attrib(fe.size),
#    (...)
#     140         src=f"ref://{fe.hash}",
#     141     )
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\view\xml_visitor.py:167, in XMLBuilder._add_asset_to_store(self, b)
#     165     meta: AssetMeta = writer.get_meta(b.data)
#     166     fe = self.store.get_file(meta.ext, meta.mime)
# --> 167     writer.write_file(b.data, fe.file)
#     168     self.store.add_file(fe)
#     169 except DispatchError:
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\multimethod\__init__.py:315, in multimethod.__call__(self, *args, **kwargs)
#     313 func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except TypeError as ex:
#     317     raise DispatchError(f"Function {func.__code__}") from ex
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\view\asset_writers.py:84, in DataTableWriter.write_file(self, x, f)
#      82     raise DPClientError("Empty DataFrame provided")
#      83 # process_df called in Arrow.save_file
# ---> 84 ArrowFormat.save_file(f, x)
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\common\datafiles.py:61, in ArrowFormat.save_file(fn, df)
#      59 @staticmethod
#      60 def save_file(fn: PathOrFile, df: pd.DataFrame):
# ---> 61     df = process_df(df)
#      62     # NOTE - can pass expected schema and columns for output df here
#      63     table: pa.Table = pa.Table.from_pandas(df, preserve_index=False)
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\common\df_processor.py:180, in process_df(df, copy)
#     177 parse_categories(df)
#     179 # convert all strings to use the arrow dtype
# --> 180 str_to_arrow_str(df)
#     182 return df
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\datapane\common\df_processor.py:136, in str_to_arrow_str(df)
#     134 if PD_VERSION in PD_1_3_GREATER:
#     135     df_str = df.select_dtypes("string")
# --> 136     df[df_str.columns] = df_str.astype("string[pyarrow]")
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5901, in NDFrame.astype(self, dtype, copy, errors)
#    5898             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899         results.append(res_col)
# -> 5901 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    5902     # GH 18099/22869: columnwise conversion to extension dtype
#    5903     # GH 24704: use iloc to handle duplicate column names
#    5904     # TODO(EA2D): special case not needed with 2D EAs
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\common.py:1480, in is_extension_array_dtype(arr_or_dtype)
#    1478     return False
#    1479 else:
# -> 1480     return registry.find(dtype) is not None
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\base.py:492, in Registry.find(self, dtype)
#     490 for dtype_type in self.dtypes:
#     491     try:
# --> 492         return dtype_type.construct_from_string(dtype)
#     493     except TypeError:
#     494         pass
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\string_.py:156, in StringDtype.construct_from_string(cls, string)
#     154     return cls(storage="python")
#     155 elif string == "string[pyarrow]":
# --> 156     return cls(storage="pyarrow")
#     157 else:
#     158     raise TypeError(f"Cannot construct a '{cls.__name__}' from '{string}'")
#
# File c:\Users\yoges\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\string_.py:109, in StringDtype.__init__(self, storage)
#     105     raise ValueError(
#     106         f"Storage must be 'python' or 'pyarrow'. Got {storage} instead."
#     107     )
#     108 if storage == "pyarrow" and pa_version_under1p01:
# --> 109     raise ImportError(
#     110         "pyarrow>=1.0.0 is required for PyArrow backed StringArray."
#     111     )
#     112 self.storage = storage
#
# ImportError: pyarrow>=1.0.0 is required for PyArrow backed StringArray.
